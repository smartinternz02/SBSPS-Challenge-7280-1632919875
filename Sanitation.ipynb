# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"Downloads/Sanitation.csv")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad             8.0                NaN          NaN
# 1   Andol-Jogipet             NaN                NaN          NaN
# 2          Armoor             4.0                NaN          NaN
# 3       Atchampet             NaN                NaN          NaN
# 4       Badangpet             NaN                NaN          NaN
# ..            ...             ...                ...          ...
# 67      Vikarabad             3.0                NaN          NaN
# 68     Wanaparthy             NaN                NaN          NaN
# 69       Warangal             1.0                NaN          NaN
# 70       Yellandu             NaN                NaN          NaN
# 71     Zaheerabad             NaN                NaN          NaN
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# ...

# %%
df.shape
# Out:
# (72, 20)

# %% [markdown]
# # TYPES OF TOILETS AND THEIR PLOTS

# %%
sns.barplot(x = 'ULB Name',
            y = 'Public Toilets',
            data = df)
# Out:
# <AxesSubplot:xlabel='ULB Name', ylabel='Public Toilets'>

# %% [markdown]
# From the above bar plot we can observe that there are some areas where public toilets are unavailable in the given dataset.

# %%
sns.barplot(x = 'ULB Name',
            y = 'Community Toilets',
            data = df)
# Out:
# <AxesSubplot:xlabel='ULB Name', ylabel='Community Toilets'>

# %% [markdown]
# This plot is the correlation between ULB Name and Community Toilets.

# %%
sns.barplot(x = 'ULB Name',
            y = 'She Toilets',
            data = df)
# Out:
# <AxesSubplot:xlabel='ULB Name', ylabel='She Toilets'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ULB Name                                 72 non-null     object
#  1   Public Toilets                           31 non-null     float64
#  2   Community Toilets                        13 non-null     float64
#  3   She Toilets                              10 non-null     float64
#  4   ODF Declared Wards                       72 non-null     int64
#  5   ODF Non Declared Wards                   72 non-null     int64
#  6   Compost Yard Location & Extent (Acrs)    72 non-null     float64
#  7   Dry Resourse Collection Center (Yes/No)  60 non-null     object
#  8   % of Door to Door Collection             72 non-null     float64
#  9   Tractors                                 72 non-null     int64
# ...

# %%
newdf=df.fillna(
{
    
    'Public Toilets':2,
    'Community Toilets':1,
    'She Toilets':1
})

# %% [markdown]
# The above code is done to normalize the missing data

# %%
newdf.head()
# Out:
#         ULB Name  Public Toilets  Community Toilets  She Toilets  \
# 0       Adilabad             8.0                1.0          1.0
# 1  Andol-Jogipet             2.0                1.0          1.0
# 2         Armoor             4.0                1.0          1.0
# 3      Atchampet             2.0                1.0          1.0
# 4      Badangpet             2.0                1.0          1.0
#
#    ODF Declared Wards  ODF Non Declared Wards  \
# 0                  36                       0
# 1                  10                      10
# 2                  23                       0
# 3                  20                       0
# 4                  20                       0
#
#    Compost Yard Location & Extent (Acrs)  \
# 0                                  36.20
# 1                                   3.27
# 2                                  11.09
# 3                                   0.00
# 4                                   0.00
#
# ...

# %%
vdf=newdf[['ULB Name','Tractors','Autos','Tricycles','Pushcarts']]

# %%
vdf
# Out:
#          ULB Name  Tractors  Autos  Tricycles  Pushcarts
# 0        Adilabad        12     18          5         30
# 1   Andol-Jogipet         1      0         12          3
# 2          Armoor         5     10          0          0
# 3       Atchampet         9      0          5          0
# 4       Badangpet         4     30         15          0
# ..            ...       ...    ...        ...        ...
# 67      Vikarabad         3     11          0          0
# 68     Wanaparthy        11      0          0          2
# 69       Warangal         0      0          0          0
# 70       Yellandu         4      2          8         24
# 71     Zaheerabad         3      4         15          0
#
# [72 rows x 5 columns]

# %% [markdown]
# # VEHICLE TYPES AND THEIR PLOTS

# %%
sns.relplot(x = 'ULB Name',
            y = 'Tractors',
            data = vdf,kind='line')

# %%
sns.relplot(x = 'ULB Name',
            y = 'Autos',
            data = vdf,kind='line')

# %%
sns.relplot(x = 'ULB Name',
            y = 'Tricycles',
            data = vdf,kind='line')

# %%
sns.relplot(x = 'ULB Name',
            y = 'Pushcarts',
            data = vdf,kind='line')

# %% [markdown]
# # HOSPITALS TYPES AND THEIR PLOTS

# %%
sns.relplot(x = 'ULB Name',
            y = 'Government Hospitals',
            data = newdf,color='red')

# %%
sns.relplot(x = 'ULB Name',
            y = 'Private Hospitals',
            data = newdf,color='green')

# %%
sns.relplot(x = 'ULB Name',
            y = 'Urban Health Centres',
            data = newdf,color='black')

# %% [markdown]
# # GARBAGE GENERATED AND GARBAGE COLLECTION

# %%
sns.relplot(x = 'ULB Name',
            y = 'Garbage generation/day (Mts)',
            data = newdf,color='red',kind='line')

# %%
sns.barplot(x = 'ULB Name',
            y = 'Garbage lifted/day (Mts)',
            data = newdf,color='green')
# Out:
# <AxesSubplot:xlabel='ULB Name', ylabel='Garbage lifted/day (Mts)'>
